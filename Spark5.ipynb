# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunal-Datacoder/Powerbi-/blob/main/Spark5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

from pyspark.sql import SparkSession
from pyspark.sql import Row
import collections


spark = SparkSession.builder.config("spark.sql.warehouse.dir","file:///C:/temp").appName("SparkSQL").getOrCreate()

# %%
def mapper(line):
  fields = line.split(',')
  return Row(ID=int(fields[0]), name = str(fields[1].encode("utf-8")),age = int(fields[2]),numFriends = int(fields[3]))

# %%
lines = spark.sparkContext.textFile("/fakefriends.csv")
people = lines.map(mapper)
lines.top
# Out:
# <bound method RDD.top of /fakefriends.csv MapPartitionsRDD[4] at textFile at NativeMethodAccessorImpl.java:0>

# %%
schemaPeople = spark.createDataFrame(people).cache()
schemaPeople.createOrReplaceTempView("People")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
queryA = spark.sql("SELECT * FROM people WHERE numFriends > 450")
for rec in queryA.collect():
  print(rec)
# Out:
# Row(ID=3, name="b'Deanna'", age=40, numFriends=465)
# Row(ID=18, name="b'Jean-Luc'", age=45, numFriends=455)
# Row(ID=28, name="b'Martok'", age=49, numFriends=476)
# Row(ID=66, name="b'Geordi'", age=21, numFriends=477)
# Row(ID=75, name="b'Morn'", age=40, numFriends=459)
# Row(ID=82, name="b'Hugh'", age=57, numFriends=465)
# Row(ID=87, name="b'Ezri'", age=31, numFriends=481)
# Row(ID=89, name="b'Worf'", age=24, numFriends=492)
# Row(ID=90, name="b'Kasidy'", age=33, numFriends=471)
# Row(ID=99, name="b'Keiko'", age=69, numFriends=491)
# Row(ID=100, name="b'Jean-Luc'", age=61, numFriends=460)
# Row(ID=106, name="b'Beverly'", age=18, numFriends=499)
# Row(ID=117, name="b'Rom'", age=52, numFriends=487)
# Row(ID=132, name="b'Odo'", age=46, numFriends=462)
# Row(ID=145, name="b'Leeta'", age=45, numFriends=470)
# Row(ID=170, name="b'Jean-Luc'", age=68, numFriends=490)
# Row(ID=175, name="b'Will'", age=38, numFriends=459)
# Row(ID=176, name="b'Worf'", age=55, numFriends=474)
# ...

# %%
schemaPeople.groupBy("age").count().orderBy("age").show()
spark.stop()
# Out:
# +---+-----+
# |age|count|
# +---+-----+
# | 18|    8|
# | 19|   11|
# | 20|    5|
# | 21|    8|
# | 22|    7|
# | 23|   10|
# | 24|    5|
# | 25|   11|
# | 26|   17|
# | 27|    8|
# | 28|   10|
# | 29|   12|
# | 30|   11|
# | 31|    8|
# | 32|   11|
# | 33|   12|
# | 34|    6|
# | 35|    8|
# | 36|   10|
# | 37|    9|
# +---+-----+
# only showing top 20 rows
